# %%
import cv2
import matplotlib.pyplot as plt

# %%
image_original = cv2.imread("./cute_cat.png")

# %%
cv2.imshow('img', image_original)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
plt.imshow(image_original)
plt.show()

# %% [markdown]
# 1. 좌우 반전시켜 출력

# %%
image_mirror = cv2.flip(image_original, 1)

# %%
plt.imshow(image_mirror)
plt.show()

# %% [markdown]
# 2. 가우시안 블러링

# %%
img_blur = cv2.GaussianBlur(image_original, (7, 7), 4)

# %%
plt.imshow(img_blur)
plt.show()
